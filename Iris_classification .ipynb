# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn import datasets
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Methods for loading datasets
# ## 1. as a dataframe
# ## 2. as an array

# %%
dataset = pd.read_csv("IRIS.csv")
dataset

# dataset = datasets.load_iris()
# dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
dataset['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Convert dataframe into array
# ## use iloc

# %%
# dataset = dataset.iloc[:,:].values

# %%
# dataset

# %% [markdown]
# # Label encoder
# ## Different methods to do so

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# lb = LabelEncoder()

# %%
# dataset["species"] = lb.fit_transform(dataset["species"])

# %%
# dataset

# %% [markdown]
# # Another way to encode

# %%
# dataset["species"] = dataset['species'].replace({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2},inplace = True)
# dataset

# %% [markdown]
# ## back to normal

# %%
# dataset['species'] = dataset['species'].map({0:"iris-setosa" , 1:"iris-versicolor" , 2: "iris-virginica"})

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Preprocessing the dataset

# %%
dataset.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # Exploratory data analysis

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dataset['sepal_length'].hist()
plt.suptitle("Sepal_length")
# Out:
# Text(0.5, 0.98, 'Sepal_length')

# %%
dataset['sepal_width'].hist()
plt.suptitle("Sepal_width")
# Out:
# Text(0.5, 0.98, 'Sepal_width')

# %%
dataset['petal_length'].hist()
plt.suptitle("Petal_length")
# Out:
# Text(0.5, 0.98, 'Petal_length')

# %%
dataset['petal_width'].hist()
plt.suptitle("Petal_width")
# Out:
# Text(0.5, 0.98, 'Petal_width')

# %% [markdown]
# ## relationship of the data features with the target using seaborn

# %%
sb.relplot(x="sepal_length" , y = "species" , hue ="species" , data = dataset)

# %%
sb.relplot(x="sepal_width" , y = "species" , hue ="species" , data = dataset)

# %%
sb.relplot(x="petal_length" , y = "species" , hue ="species" , data = dataset)

# %%
sb.relplot(x="petal_width" , y = "species" , hue ="species" , data = dataset)

# %% [markdown]
# ## complete pairplots using seaborn

# %%
sb.pairplot(dataset , hue = "species")

# %% [markdown]
# ## scatter plots using matplotlib

# %%
color = ['red' , 'orange' , 'green']
species = ['Iris-setosa' , 'Iris-versicolor' , 'Iris-virginica']

# %%
for i in range(3):
    x = dataset[dataset["species"] == species[i]]
    plt.scatter(x['sepal_length'] , x['sepal_width'] , c=color[i] , label = species[i])

plt.xlabel("Sepal_length")
plt.ylabel("Sepal_width")
plt.legend()

# %%
for i in range(3):
    x = dataset[dataset["species"] == species[i]]
    plt.scatter(x['petal_length'] , x['petal_width'] , c=color[i] , label = species[i])

plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.legend()

# %%
for i in range(3):
    x = dataset[dataset["species"] == species[i]]
    plt.scatter(x['sepal_length'] , x['petal_length'] , c=color[i] , label = species[i])

plt.xlabel("Sepal_length")
plt.ylabel("Petal_length")
plt.legend()

# %%
for i in range(3):
    x = dataset[dataset["species"] == species[i]]
    plt.scatter(x['sepal_width'] , x['petal_width'] , c=color[i] , label = species[i])

plt.xlabel("Sepal_width")
plt.ylabel("Petal_width")
plt.legend()

# %% [markdown]
# ## correlation matrix using matplotlib

# %%
lb = LabelEncoder()
dataset["species"] = lb.fit_transform(dataset["species"])
dataset.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   species
# sepal_length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal_length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal_width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
matrix = dataset.corr()
plt.imshow(matrix,cmap = "Blues")
plt.colorbar()

#extracting variable names 
variables = []
for i in matrix.columns:
  variables.append(i)

    
# Adding labels to the matrix
plt.xticks(range(len(matrix)), variables, rotation=45, ha='right')
plt.yticks(range(len(matrix)), variables)

# Display the plot
plt.show()

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## correlation matrix using seaborn

# %%
matrix = dataset.corr()
# fig,ax = plt.subplots(figsize=(5,5))
# sb.heatmap(matrix,cmap = "Greens" ,annot = True , ax = ax)

sb.heatmap(matrix,cmap = "Greens" ,annot = True )
# Out:
# <Axes: >

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
dataset['species'] = dataset['species'].map({0:"iris-setosa" , 1:"iris-versicolor" , 2: "iris-virginica"})

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     iris-setosa
# 1             4.9          3.0           1.4          0.2     iris-setosa
# 2             4.7          3.2           1.3          0.2     iris-setosa
# 3             4.6          3.1           1.5          0.2     iris-setosa
# 4             5.0          3.6           1.4          0.2     iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  iris-virginica
# 146           6.3          2.5           5.0          1.9  iris-virginica
# 147           6.5          3.0           5.2          2.0  iris-virginica
# 148           6.2          3.4           5.4          2.3  iris-virginica
# 149           5.9          3.0           5.1          1.8  iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Model Training

# %% [markdown]
# ## method 1: direct

# %%
x = dataset[["sepal_length" , "sepal_width" , "petal_length" , "petal_width"]]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y = dataset["species"]
y
# Out:
# 0         iris-setosa
# 1         iris-setosa
# 2         iris-setosa
# 3         iris-setosa
# 4         iris-setosa
#             ...
# 145    iris-virginica
# 146    iris-virginica
# 147    iris-virginica
# 148    iris-virginica
# 149    iris-virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# ## method 2: using iloc

# %%
# x = dataset.iloc[:,0:-1]
# # x = dataset.iloc[:,0:4]
# x

# %%
# y = dataset.iloc[:,-1]
# # y = dataset.species
# y

# %% [markdown]
# ## method 3 : using drop function

# %%
# x = dataset.drop(columns =["species"])
# y = dataset.species

# %%
# x

# %%
# y

# %% [markdown]
# ## now split data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test, y_train , y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 144           6.7          3.3           5.7          2.5
# 11            4.8          3.4           1.6          0.2
# 29            4.7          3.2           1.6          0.2
# 84            5.4          3.0           4.5          1.5
# 111           6.4          2.7           5.3          1.9
# ..            ...          ...           ...          ...
# 32            5.2          4.1           1.5          0.1
# 36            5.5          3.5           1.3          0.2
# 139           6.9          3.1           5.4          2.1
# 5             5.4          3.9           1.7          0.4
# 138           6.0          3.0           4.8          1.8
#
# [105 rows x 4 columns]

# %%
y_train
# Out:
# 144     iris-virginica
# 11         iris-setosa
# 29         iris-setosa
# 84     iris-versicolor
# 111     iris-virginica
#             ...
# 32         iris-setosa
# 36         iris-setosa
# 139     iris-virginica
# 5          iris-setosa
# 138     iris-virginica
# Name: species, Length: 105, dtype: object

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 49            5.0          3.3           1.4          0.2
# 82            5.8          2.7           3.9          1.2
# 16            5.4          3.9           1.3          0.4
# 91            6.1          3.0           4.6          1.4
# 104           6.5          3.0           5.8          2.2
# 69            5.6          2.5           3.9          1.1
# 136           6.3          3.4           5.6          2.4
# 147           6.5          3.0           5.2          2.0
# 122           7.7          2.8           6.7          2.0
# 102           7.1          3.0           5.9          2.1
# 87            6.3          2.3           4.4          1.3
# 101           5.8          2.7           5.1          1.9
# 112           6.8          3.0           5.5          2.1
# 81            5.5          2.4           3.7          1.0
# 12            4.8          3.0           1.4          0.1
# ...

# %%
y_test
# Out:
# 49         iris-setosa
# 82     iris-versicolor
# 16         iris-setosa
# 91     iris-versicolor
# 104     iris-virginica
# 69     iris-versicolor
# 136     iris-virginica
# 147     iris-virginica
# 122     iris-virginica
# 102     iris-virginica
# 87     iris-versicolor
# 101     iris-virginica
# 112     iris-virginica
# 81     iris-versicolor
# 12         iris-setosa
# 105     iris-virginica
# 34         iris-setosa
# 41         iris-setosa
# 56     iris-versicolor
# 26         iris-setosa
# 75     iris-versicolor
# 50     iris-versicolor
# 118     iris-virginica
# 124     iris-virginica
# 62     iris-versicolor
# 33         iris-setosa
# 142     iris-virginica
# 108     iris-virginica
# 131     iris-virginica
# 110     iris-virginica
# 100     iris-virginica
# 94     iris-versicolor
# 18         iris-setosa
# 120     iris-virginica
# 54     iris-versicolor
# 127     iris-virginica
# 86     iris-versicolor
# 2          iris-setosa
# 117     iris-virginica
# 25         iris-setosa
# ...

# %% [markdown]
# ## Now apply different models

# %% [markdown]
# ### 1 .Logistic regression for multiclasses

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %% [markdown]
# #### Using cross-validation to evaluate our model

# %%
from sklearn.model_selection import cross_val_score , cross_val_predict
accuracies = cross_val_score(lr,x_train , y_train , cv = 5 , scoring="accuracy")
# Out:
# C:\Users\Hp\anaconda3\envs\Tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\envs\Tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
np.mean(accuracies)
# Out:
# 0.9333333333333333

# %%
# # Perform 5-fold cross-validation
# cv_scores = cross_val_score(lr, x, y, cv=5)

# # Print the cross-validation scores and mean
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {cv_scores.mean():.2f}")

# %% [markdown]
# ### Where are we misclassifying points?

# %%
y_pred = cross_val_predict(lr,x_train , y_train , cv=5)
# Out:
# C:\Users\Hp\anaconda3\envs\Tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\envs\Tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
y_pred
# Out:
# array(['iris-virginica', 'iris-setosa', 'iris-setosa', 'iris-versicolor',
#        'iris-virginica', 'iris-setosa', 'iris-setosa', 'iris-virginica',
#        'iris-setosa', 'iris-setosa', 'iris-virginica', 'iris-versicolor',
#        'iris-setosa', 'iris-versicolor', 'iris-virginica',
#        'iris-versicolor', 'iris-virginica', 'iris-setosa', 'iris-setosa',
#        'iris-versicolor', 'iris-virginica', 'iris-versicolor',
#        'iris-versicolor', 'iris-versicolor', 'iris-virginica',
#        'iris-virginica', 'iris-setosa', 'iris-versicolor',
#        'iris-virginica', 'iris-virginica', 'iris-setosa',
#        'iris-virginica', 'iris-setosa', 'iris-setosa', 'iris-setosa',
#        'iris-versicolor', 'iris-versicolor', 'iris-versicolor',
#        'iris-versicolor', 'iris-virginica', 'iris-setosa',
#        'iris-virginica', 'iris-virginica', 'iris-virginica',
#        'iris-versicolor', 'iris-versicolor', 'iris-virginica',
# ...

# %%
predicted_correctly_mask = y_pred == y_train

# %%
not_predicted_correctly = -predicted_correctly_mask

# %%
x_train[not_predicted_correctly]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 83            6.0          2.7           5.1          1.6
# 119           6.0          2.2           5.0          1.5
# 70            5.9          3.2           4.8          1.8
# 106           4.9          2.5           4.5          1.7
# 77            6.7          3.0           5.0          1.7
# 126           6.2          2.8           4.8          1.8
# 138           6.0          3.0           4.8          1.8

# %%
x_predictions = x_train.copy()

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %% [markdown]
# #### here the target and the target_names are the y_test datavalue
# #### and predictions and prediction_label are the values we predicted after training the model on train dataset

# %%
x_predictions["target"] = lb.fit_transform(y_train)

# %%
x_predictions["target_name"] = y_train

# %%
x_predictions["correct_predictions"] = predicted_correctly_mask

# %%
x_predictions["predictions"] = lb.fit_transform(y_pred)

# %%
x_predictions["prediction_label"] = y_pred

# %%
x_predictions
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target  \
# 144           6.7          3.3           5.7          2.5       2
# 11            4.8          3.4           1.6          0.2       0
# 29            4.7          3.2           1.6          0.2       0
# 84            5.4          3.0           4.5          1.5       1
# 111           6.4          2.7           5.3          1.9       2
# ..            ...          ...           ...          ...     ...
# 32            5.2          4.1           1.5          0.1       0
# 36            5.5          3.5           1.3          0.2       0
# 139           6.9          3.1           5.4          2.1       2
# 5             5.4          3.9           1.7          0.4       0
# 138           6.0          3.0           4.8          1.8       2
#
#          target_name  correct_predictions  predictions prediction_label
# 144   iris-virginica                 True            2   iris-virginica
# ...

# %%
sb.scatterplot(x="petal_length" , y = "petal_width" , hue ="prediction_label" , data = x_predictions)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sb.scatterplot(x="petal_length" , y = "petal_width" , hue ="target_name" , data = x_predictions)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sb.scatterplot(x="petal_length" , y = "petal_width" , hue ="correct_predictions" , data = x_predictions)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# ### Training our model on the test dataset and predicting the values and finding out the accuracies are done after cross validation and model tuning

# %%
# lr.fit(x_train , y_train)

# %%
# lr.predict(x_test)

# %%
# y_test

# %%
# print("Accuracy on train cases :" , lr.score(x_train,y_train)*100)

# %%
# print("Accuracy on test cases :" , lr.score(x_test,y_test)*100)

# %% [markdown]
# # Model tuning
# What is model tuning ?
# Model tuning is trying to determine the parameters of your model( these are also called "hyperparameters") that mazimize the model performance

# %%
# from sklearn.ensemble import RandomForestClassifier

# %%
# model = RandomForestClassifier()

# %%
# acc = cross_val_score(model,x_train , y_train , cv=5 , scoring ="accuracy")

# %%
# np.mean(acc)

# %%
# we will work with changing the regularization parameter 
for reg_para in (0.1 , 0.5 , 1 , 1.5 , 2 , 2.5 , 3 , 3.5 , 3.9 , 4 , 4.5):
    print(reg_para)
    model = LogisticRegression(max_iter = 200 , C= reg_para)
    accuracies = cross_val_score(model , x_train , y_train , cv=5 , scoring = "accuracy")
    print(f"Accuracy : {np.mean(accuracies)*100}%")
# Out:
# 0.1
# Accuracy : 91.42857142857143%
# 0.5
# Accuracy : 93.33333333333333%
# 1
# Accuracy : 93.33333333333333%
# 1.5
# Accuracy : 92.38095238095238%
# 2
# Accuracy : 92.38095238095238%
# 2.5
# Accuracy : 92.38095238095238%
# 3
# Accuracy : 93.33333333333333%
# 3.5
# Accuracy : 94.28571428571428%
# 3.9
# Accuracy : 94.28571428571428%
# 4
# Accuracy : 94.28571428571428%
# 4.5
# Accuracy : 94.28571428571428%

# %% [markdown]
# # Final Model
# how well is our model gonna work on test datase...
# previously we were doing all sorts of operations on train dataset

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 49            5.0          3.3           1.4          0.2
# 82            5.8          2.7           3.9          1.2
# 16            5.4          3.9           1.3          0.4
# 91            6.1          3.0           4.6          1.4
# 104           6.5          3.0           5.8          2.2
# 69            5.6          2.5           3.9          1.1
# 136           6.3          3.4           5.6          2.4
# 147           6.5          3.0           5.2          2.0
# 122           7.7          2.8           6.7          2.0
# 102           7.1          3.0           5.9          2.1
# 87            6.3          2.3           4.4          1.3
# 101           5.8          2.7           5.1          1.9
# 112           6.8          3.0           5.5          2.1
# 81            5.5          2.4           3.7          1.0
# 12            4.8          3.0           1.4          0.1
# ...

# %%
y_test
# Out:
# 49         iris-setosa
# 82     iris-versicolor
# 16         iris-setosa
# 91     iris-versicolor
# 104     iris-virginica
# 69     iris-versicolor
# 136     iris-virginica
# 147     iris-virginica
# 122     iris-virginica
# 102     iris-virginica
# 87     iris-versicolor
# 101     iris-virginica
# 112     iris-virginica
# 81     iris-versicolor
# 12         iris-setosa
# 105     iris-virginica
# 34         iris-setosa
# 41         iris-setosa
# 56     iris-versicolor
# 26         iris-setosa
# 75     iris-versicolor
# 50     iris-versicolor
# 118     iris-virginica
# 124     iris-virginica
# 62     iris-versicolor
# 33         iris-setosa
# 142     iris-virginica
# 108     iris-virginica
# 131     iris-virginica
# 110     iris-virginica
# 100     iris-virginica
# 94     iris-versicolor
# 18         iris-setosa
# 120     iris-virginica
# 54     iris-versicolor
# 127     iris-virginica
# 86     iris-versicolor
# 2          iris-setosa
# 117     iris-virginica
# 25         iris-setosa
# ...

# %% [markdown]
# ### train our model using our full training dataset

# %%
model.fit(x_train , y_train)
# Out:
# LogisticRegression(C=4.5, max_iter=200)

# %%
y_test_predictions = model.predict(x_test)

# %%
# now check if the y_test and y_test_predictions are same or not 
test_set_correctly_classified = y_test_predictions == y_test
test_set_accuracy = np.mean(test_set_correctly_classified)

# %%
print(f"Test set accuracy : {test_set_accuracy*100}")
# Out:
# Test set accuracy : 100.0

# %%
## looking at the missclassified points 
x_predictions_test = x_test.copy()
x_predictions_test["correct_predictions"] = test_set_correctly_classified
x_predictions_test["predictions"] = y_test_predictions
x_predictions_test["actual_values"] = y_test

# %%
x_predictions_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 49            5.0          3.3           1.4          0.2
# 82            5.8          2.7           3.9          1.2
# 16            5.4          3.9           1.3          0.4
# 91            6.1          3.0           4.6          1.4
# 104           6.5          3.0           5.8          2.2
# 69            5.6          2.5           3.9          1.1
# 136           6.3          3.4           5.6          2.4
# 147           6.5          3.0           5.2          2.0
# 122           7.7          2.8           6.7          2.0
# 102           7.1          3.0           5.9          2.1
# 87            6.3          2.3           4.4          1.3
# 101           5.8          2.7           5.1          1.9
# 112           6.8          3.0           5.5          2.1
# 81            5.5          2.4           3.7          1.0
# 12            4.8          3.0           1.4          0.1
# ...

# %%
sb.scatterplot(x="petal_length" , y = "petal_width" , hue ="predictions" , data = x_predictions_test)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sb.scatterplot(x="petal_length" , y = "petal_width" , hue ="actual_values" , data = x_predictions_test)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sb.scatterplot(x="petal_length" , y = "petal_width" , hue ="correct_predictions" , data = x_predictions_test)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# # Conclusion
# ### In conclusion, we have achieved an accuracy of 95.5% on test dataset using logistic regression model

# %% [markdown]
# # Using tensorflow and keras

# %%
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# print(x_train[:1])
# x_train = sc.fit_transform(x_train)
# x_test = sc.transform(x_test)
# print(x_train[:1])

# %%
# y_train

# %%
# y_train = lb.transform(y_train)

# %%
# y_train

# %%
# from tensorflow import keras
# y_train = keras.utils.to_categorical(y_train , num_classes=3)
# print(y_train[:5])

# %%
# from keras.models import Sequential
# from keras.layers import Dense,Dropout

# %%
import tensorflow as tf
def readTrainTestData():
    
    col_norm = ["sepal_length" , "sepal_width" , "petal_length" , "petal_width"]
    X_DATA = dataset[col_norm]
    X_DATA = X_DATA.apply(lambda x:((x-x.min())/(x.max()-x.min())))
   
    lb = LabelEncoder()
    Y_DATA = dataset["species"]
    Y_DATA = dataset["species"].map({"iris-setosa" : 0 , "iris-versicolor" : 1 , "iris-virginica" : 2})

    X_TRAIN , X_TEST , Y_TRAIN , Y_TEST = train_test_split(X_DATA , Y_DATA , test_size = 0.3 , random_state = 101)

    return X_TRAIN , X_TEST , Y_TRAIN , Y_TEST

# %%
def create_feature_column():
    feat_sepal_length = tf.feature_column.numeric_column("sepal_length")
    feat_sepal_width = tf.feature_column.numeric_column("sepal_width")
    feat_petal_length = tf.feature_column.numeric_column("petal_length")
    feat_petal_width = tf.feature_column.numeric_column("petal_width")

    feature_column = [feat_sepal_length , feat_sepal_width, feat_petal_length , feat_petal_width]
    return feature_column

# %%
X_TRAIN , X_TEST , Y_TRAIN , Y_TEST = readTrainTestData()
feature_column = create_feature_column()

input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_TRAIN , y=Y_TRAIN , batch_size = 40 , num_epochs = 1000 , shuffle = True)

eval_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_TEST , y=Y_TEST , batch_size = 40 , num_epochs = 1 , shuffle = False)

predict_input_fn =tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_TEST, num_epochs = 1 , shuffle = False)

# %%
model = tf.estimator.LinearClassifier(feature_columns = feature_column, n_classes = 3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Hp\AppData\Local\Temp\tmpptnoe6hz
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Hp\\AppData\\Local\\Temp\\tmpptnoe6hz', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
history = model.train(input_fn = input_func , steps = 1000)
# Out:
# WARNING:tensorflow:From C:\Users\Hp\anaconda3\envs\Tensorflow\lib\site-packages\tensorflow\python\training\training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From C:\Users\Hp\anaconda3\envs\Tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:60: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# ...

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-06-26T04:05:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Hp\AppData\Local\Temp\tmpptnoe6hz\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.34133s
# INFO:tensorflow:Finished evaluation at 2024-06-26-04:05:09
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.95555556, average_loss = 0.2999555, global_step = 1000, loss = 0.31243765
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Hp\AppData\Local\Temp\tmpptnoe6hz\model.ckpt-1000

# %%
results["accuracy"]
# Out:
# 0.95555556

# %%
# import scikitplot as skplt
# from sklearn.metrics import confusion_matrix,classification_report
# skplt.metrics.plot_confusion_matrix(Y_TEST, prediction , figsize=(6,6), title="confusion matric")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[534], line 1
# ----> 1 import scikitplot as skplt
#       2 from sklearn.metrics import confusion_matrix,classification_report
#       3 skplt.metrics.plot_confusion_matrix(Y_TEST, prediction , figsize=(6,6), title="confusion matric")
#
# File ~\anaconda3\envs\Tensorflow\lib\site-packages\scikitplot\__init__.py:2
#       1 from __future__ import absolute_import, division, print_function, unicode_literals
# ----> 2 from . import metrics, cluster, decomposition, estimators
#       3 __version__ = '0.3.7'
#       6 from scikitplot.classifiers import classifier_factory
#
# File ~\anaconda3\envs\Tensorflow\lib\site-packages\scikitplot\metrics.py:27
#      24 from sklearn.calibration import calibration_curve
#      25 from sklearn.utils import deprecated
# ---> 27 from scipy import interp
# ...

# %% [markdown]
# ## Conclusion
# ### Using tensorflow also we are having an accuracy of 95.5%

# %% [markdown]
# ### 2. K-NEAREST NEIGHBOURS (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN = KNeighborsClassifier(n_neighbors = 5)

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
KNN.predict(x_test)
# Out:
# array([0, 1, 0, 1, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 0, 2, 0, 0, 1, 0, 1, 1,
#        2, 2, 1, 0, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2, 1, 2, 0,
#        0])

# %%
print("Accuracy on train cases :" , KNN.score(x_train,y_train)*100)
# Out:
# Accuracy on train cases : 95.23809523809523

# %%
print("Accuracy on test cases :" , KNN.score(x_test,y_test)*100)
# Out:
# Accuracy on test cases : 0.0

# %% [markdown]
# ### 3.Knaive Bayes - overfitting model !!!

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train , y_train)
# Out:
# GaussianNB()

# %%
gnb.predict(x_test)
# Out:
# array([0, 1, 0, 1, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 0, 2, 0, 0, 1, 0, 1, 1,
#        2, 2, 1, 0, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2, 1, 2, 0,
#        0])

# %%
print("Accuracy on train cases :" , gnb.score(x_train,y_train)*100)
# Out:
# Accuracy on train cases : 94.28571428571428

# %%
print("Accuracy on test cases :" , gnb.score(x_test,y_test)*100)
# Out:
# Accuracy on test cases : 0.0

# %% [markdown]
# ### 4. SVM - overfitting cause train accuracy is 100% but test accuracy is 97.7% !!!

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel = "linear")

# %%
svc.fit(x_train , y_train)
# Out:
# SVC(kernel='linear')

# %%
svc.predict(x_test)
# Out:
# array([0, 1, 0, 1, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 0, 2, 0, 0, 1, 0, 1, 1,
#        2, 2, 1, 0, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2, 1, 2, 0,
#        0])

# %%
print("Accuracy on train cases :" , svc.score(x_train,y_train)*100)
# Out:
# Accuracy on train cases : 97.14285714285714

# %%
print("Accuracy on test cases :" , svc.score(x_test,y_test)*100)
# Out:
# Accuracy on test cases : 0.0

# %% [markdown]
# ### 5. Decision Tree - overfitting !!!

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Tree = DecisionTreeClassifier(criterion = "gini")

# %%
Tree.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
Tree.predict(x_test)
# Out:
# array([0, 1, 0, 1, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 0, 2, 0, 0, 1, 0, 1, 1,
#        2, 2, 1, 0, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2, 1, 2, 0,
#        0])

# %%
print("Accuracy on train cases :" , Tree.score(x_train,y_train)*100)
# Out:
# Accuracy on train cases : 100.0

# %%
print("Accuracy on test cases :" , Tree.score(x_test,y_test)*100)
# Out:
# Accuracy on test cases : 0.0

# %%
from sklearn import tree
tree.plot_tree(Tree)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[3] <= 0.75\ngini = 0.663\nsamples = 105\nvalue = [38, 37, 30]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\ngini = 0.495\nsamples = 67\nvalue = [0, 37, 30]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\ngini = 0.214\nsamples = 41\nvalue = [0, 36, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %%
Treeen = DecisionTreeClassifier(criterion = "entropy")

# %%
Treeen.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
Treeen.predict(x_test)
# Out:
# array([0, 1, 0, 1, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 0, 2, 0, 0, 1, 0, 1, 1,
#        2, 2, 1, 0, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2, 1, 2, 0,
#        0])

# %%
print("Accuracy on train cases :" , Treeen.score(x_train,y_train)*100)
# Out:
# Accuracy on train cases : 100.0

# %%
print("Accuracy on test cases :" , Treeen.score(x_test,y_test)*100)
# Out:
# Accuracy on test cases : 0.0

# %%
from sklearn import tree

# %%
tree.plot_tree(Treeen)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[2] <= 2.45\nentropy = 1.577\nsamples = 105\nvalue = [38, 37, 30]'),
#  Text(0.4230769230769231, 0.75, 'entropy = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\nentropy = 0.992\nsamples = 67\nvalue = [0, 37, 30]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\nentropy = 0.535\nsamples = 41\nvalue = [0, 36, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\nentropy = 0.187\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.07692307692307693, 0.25, 'entropy = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.23076923076923078, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[2] <= 5.45\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %% [markdown]
# ### 6. Random Forest - overfitting !!!

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators = 100 , criterion = "entropy")

# %%
rfc.fit(x_train , y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
rfc.predict(x_test)
# Out:
# array([0, 1, 0, 1, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 0, 2, 0, 0, 1, 0, 1, 1,
#        2, 2, 1, 0, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2, 1, 2, 0,
#        0])

# %%
print("Accuracy on train cases :" , rfc.score(x_train,y_train)*100)
# Out:
# Accuracy on train cases : 100.0

# %%
print("Accuracy on test cases :" , rfc.score(x_test,y_test)*100)
# Out:
# Accuracy on test cases : 0.0
